# %% [markdown]
# **pytorch prednet practice**
#
# **train and test preprocessed kitti data**
#
# **using google colaboratory**

# %% [markdown]
# clone source files

# %%
# !git clone https://github.com/shun60s/pytorch-prednet-practice

# %% [markdown]
# change working directory

# %%
# %cd pytorch-prednet-practice

# %% [markdown]
# check file tree

# %%
# !ls -l
# Out:
# total 104
# -rw-r--r-- 1 root root  5179 Mar 25 03:36 convlstmcell.py
# drwxr-xr-x 2 root root  4096 Mar 25 03:36 docs
# -rw-r--r-- 1 root root 22215 Mar 25 03:36 hickle.py
# drwxr-xr-x 2 root root  4096 Mar 25 03:36 kitti_data
# -rw-r--r-- 1 root root  2779 Mar 25 03:36 kitti_data.py
# -rw-r--r-- 1 root root  4325 Mar 25 03:36 kitti_test.py
# -rw-r--r-- 1 root root 10587 Mar 25 03:36 kitti_train.py
# -rw-r--r-- 1 root root  1109 Mar 25 03:36 LICENSE_hickle
# -rw-r--r-- 1 root root  1063 Mar 25 03:36 License_prednet.txt
# -rw-r--r-- 1 root root  1117 Mar 25 03:36 LICENSE_torchMoji
# drwxr-xr-x 2 root root  4096 Mar 25 03:36 logs
# -rw-r--r-- 1 root root  7247 Mar 25 03:36 prednet.py
# -rw-r--r-- 1 root root   736 Mar 25 03:36 README_leido_pytorch-prednet.md
# -rw-r--r-- 1 root root  2329 Mar 25 03:36 README.md
# drwxr-xr-x 2 root root  4096 Mar 25 03:36 results
# drwxr-xr-x 2 root root  4096 Mar 25 03:36 trained

# %% [markdown]
# get preprocessed KITTI data (2G) and unzip it

# %%
# !wget -P "/kitti_data" www.dropbox.com/s/rpwlnn6j39jjme4/kitti_data.zip?dl=0

# %%
# !unzip "/kitti_data/kitti_data.zip?dl=0" -d ./kitti_data/

# %% [markdown]
# train with GPU,  set gpu-id= 0
#
# specify number of epoch(--epoch)
#
# it will take aroud 5 minutes per one epoch

# %%
# !python kitti_train.py --gpu-id 0 --epoch 2

# %% [markdown]
# test predicted
#
# specify output file number(--num-output)

# %%
# !python kitti_test.py --gpu-id 0  --num-output 10

# %% [markdown]
# test extrapolated
#
# specify extrap_start_time(-et) < num of time steps(-nt)

# %%
# !python kitti_test.py --gpu-id 0 --nt 10 --et 7 -num-output 10
